# %%
import numpy as np
import pandas as p
import matplotlib.pyplot as plt
import seaborn as sns
print("libraries imported")
# Out:
# libraries imported

# %%
df = p.read_csv('tips.csv')
sns.load_dataset = lambda _: df
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# <h5>Relational plot -> scatter plot, Line plot</h5>

# %%
sns.relplot(x='tip', y='total_bill', data=df, hue='sex', style='smoker', )
plt.show()

# %%
sns.relplot(x='tip', y='total_bill', data=df, hue='sex', style='smoker', col='day')
plt.show()

# %%
sns.relplot(x='tip', y='total_bill', data=df, hue='time', style='smoker', col='day')
plt.show()

# %%
sns.relplot(x='tip', y='total_bill', data=df, hue='time', col='day')
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.relplot(x='size', y='total_bill', data=df, style='smoker', col='day', kind='line')
plt.show()

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# <h3>Categrical PLot</h3>

# %%
sns.catplot(x='smoker', y='total_bill', data=df, hue='sex')
plt.title("Strip-Chart")
plt.show()

# %%
sns.catplot(x='smoker', y='total_bill', data=df, hue='sex',kind='swarm')
plt.title("Swarm-Chart")
plt.show()

# %%
sns.catplot(x='smoker', y='total_bill', data=df, hue='sex',kind='violin')
plt.title("Voilin-Chart")
plt.show()

# %%
sns.catplot(x='smoker', y='total_bill', data=df, hue='sex',kind='boxen')
plt.title("Boxen-Chart")
plt.show()

# %%
sns.catplot(x='smoker', y='total_bill', data=df, hue='sex',kind='point')
plt.title("Point-Chart")
plt.show()

# %%
sns.catplot(x='smoker', y='total_bill', data=df, hue='sex',kind='bar')
plt.title("Count-Chart")
plt.show()

# %%
titanic = sns.load_dataset('titanic.csv')
titanic
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
