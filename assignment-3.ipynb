# %% [markdown]
# <h3>Assignment of Matplotlib library in line plot</h3>

# %%
import numpy as np
import pandas as p
import matplotlib.pyplot as plt
print("libraries imported")
# Out:
# libraries imported

# %% [markdown]
# <h4>Make a starting letter of your name using line plot</h4>

# %%
letter = [700, 700, 700, 500, 300, 100]
x_axis = [100, 700, 400, 400, 400, 400]
plt.plot(x_axis , letter, marker = ".", mfc = "black", lw = 2)
plt.title("Letter T")
plt.show()
